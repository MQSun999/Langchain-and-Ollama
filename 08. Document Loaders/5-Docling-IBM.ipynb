# %% [markdown]
# ### 🤖 LLM and AI Agent Development Courses
# **✨ All courses available for just ₹399 INR / $9.99 USD ✨**
#
# | Course | Description | Enroll |
# |--------|-------------|---------|
# | **🎯 Master OpenAI Agent Builder** | Build and deploy AI agents visually using OpenAI Agent Builder, ChatKit, RAG, Chatbot, AI Assistant with MCP, AWS, RDS MySQL | [Enroll Now](https://kgptalkie.com/agent-builder) |
# | **🔥 MCP Mastery** | Build MCP servers & clients with Python, Streamlit, ChromaDB, LangChain, LangGraph agents, and Ollama integrations | [Enroll Now](https://kgptalkie.com/mcp) |
# | **📊 Private Agentic RAG with LangChain** | Step-by-Step Guide to RAG with LangChain v1, LangGraph, and Ollama (Qwen3, Gemma3, DeepSeek-R1, LLAMA, FAISS) | [Enroll Now](https://kgptalkie.com/agentic-rag) |
# | **🔧 Master LangGraph and LangChain** | Agentic RAG and Chatbot, AI Agent with LangChain v1, Qwen3, Gemma3, DeepSeek-R1, LLAMA 3.2, FAISS Vector Database | [Enroll Now](https://kgptalkie.com/langgraph) |
# | **⚡ Master Langchain and Ollama** | Master Langchain v1, Local LLM Projects with Ollama, Qwen3, Gemma3, DeepSeek-R1, LLAMA 3.2, Complete Integration Guide | [Enroll Now](https://kgptalkie.com/langchain) |
# | **🔬 Fine Tuning LLM** | Learn transformer architecture fundamentals and fine-tune LLMs with custom datasets | [Enroll Now](https://kgptalkie.com/fine-tuning-llm) |
#
# ---
#
# ### 🌐 Join the Community & Stay Connected
#
# - 🔗 **Join the Discord Community:** https://discord.gg/RFjwbkNa
# - 📺 **Subscribe on YouTube (63K+ learners):** http://www.youtube.com/@KGPTalkie
#
# ---

# %% [markdown]
# ## Document Loaders | Docling

# %% [markdown]
# ### Basic Markdown Extraction

# %% [markdown]
# https://github.com/docling-project/docling

# %%
from docling.document_converter import DocumentConverter
import os
from pathlib import Path

# %%
os.environ["HF_HUB_DISABLE_SYMLINKS"] = "1"

# %%
import onnxruntime as ort
print(ort.get_device())
# Out:
# GPU

# %%
import onnxruntime as ort
print(ort.get_available_providers())
# 预期输出必须包含: ['CUDAExecutionProvider', 'CPUExecutionProvider']
# Out:
# ['TensorrtExecutionProvider', 'CUDAExecutionProvider', 'CPUExecutionProvider']

# %%
converter = DocumentConverter()

file_path = "data/Apple-10-Q-2025-Q1.pdf"
file_path = Path(file_path)

result = converter.convert(file_path)
# Out:
# [INFO] 2026-02-23 17:06:52,409 [RapidOCR] base.py:22: Using engine_name: onnxruntime
# [INFO] 2026-02-23 17:06:52,415 [RapidOCR] download_file.py:60: File exists and is valid: D:\Anaconda\envs\langchainv1.0\Lib\site-packages\rapidocr\models\ch_PP-OCRv4_det_infer.onnx
# [INFO] 2026-02-23 17:06:52,416 [RapidOCR] main.py:53: Using D:\Anaconda\envs\langchainv1.0\Lib\site-packages\rapidocr\models\ch_PP-OCRv4_det_infer.onnx
# [INFO] 2026-02-23 17:06:52,512 [RapidOCR] base.py:22: Using engine_name: onnxruntime
# [INFO] 2026-02-23 17:06:52,514 [RapidOCR] download_file.py:60: File exists and is valid: D:\Anaconda\envs\langchainv1.0\Lib\site-packages\rapidocr\models\ch_ppocr_mobile_v2.0_cls_infer.onnx
# [INFO] 2026-02-23 17:06:52,514 [RapidOCR] main.py:53: Using D:\Anaconda\envs\langchainv1.0\Lib\site-packages\rapidocr\models\ch_ppocr_mobile_v2.0_cls_infer.onnx
# [INFO] 2026-02-23 17:06:52,554 [RapidOCR] base.py:22: Using engine_name: onnxruntime
# [INFO] 2026-02-23 17:06:52,562 [RapidOCR] download_file.py:60: File exists and is valid: D:\Anaconda\envs\langchainv1.0\Lib\site-packages\rapidocr\models\ch_PP-OCRv4_rec_infer.onnx
# [INFO] 2026-02-23 17:06:52,563 [RapidOCR] main.py:53: Using D:\Anaconda\envs\langchainv1.0\Lib\site-packages\rapidocr\models\ch_PP-OCRv4_rec_infer.onnx
# Stage preprocess failed for run 1, pages [42]: std::bad_alloc
# Stage preprocess failed for run 1, pages [43]: std::bad_alloc
# Stage preprocess failed for run 1, pages [44]: std::bad_alloc
# Stage preprocess failed for run 1, pages [45]: std::bad_alloc
# Stage preprocess failed for run 1, pages [46]: std::bad_alloc
# Stage preprocess failed for run 1, pages [47]: std::bad_alloc
# Stage preprocess failed for run 1, pages [48]: std::bad_alloc
# Stage preprocess failed for run 1, pages [49]: std::bad_alloc
# Stage preprocess failed for run 1, pages [50]: std::bad_alloc
# Stage preprocess failed for run 1, pages [51]: std::bad_alloc

# %%
import os
os.makedirs("docling", exist_ok=True)

markdown = result.document.export_to_markdown()
with open(f"docling/{file_path.stem}.md", "w", encoding="utf-8") as f:
    f.write(markdown)

# %%
html = result.document.export_to_html()
with open(f"docling/{file_path.stem}.html", "w", encoding="utf-8") as f:
    f.write(html)

# %%
def convert_and_save(file_path):
    file_path = Path(file_path)
    result = converter.convert(file_path)

    markdown = result.document.export_to_markdown()
    with open(f"docling/{file_path.stem}.md", "w", encoding="utf-8") as f:
        f.write(markdown)

# %%
convert_and_save("data/scansmpl.pdf")
# Out:
# 2025-10-22 12:28:34,269 - INFO - detected formats: [<InputFormat.PDF: 'pdf'>]
# 2025-10-22 12:28:34,270 - INFO - Going to convert document batch...
# 2025-10-22 12:28:34,271 - INFO - Processing document scansmpl.pdf
# 2025-10-22 12:28:40,648 - INFO - Finished converting document scansmpl.pdf in 6.39 sec.

# %%
convert_and_save("data/job_description.docx")
# Out:
# 2025-10-22 12:28:40,656 - INFO - detected formats: [<InputFormat.DOCX: 'docx'>]
# 2025-10-22 12:28:40,659 - INFO - Going to convert document batch...
# 2025-10-22 12:28:40,659 - INFO - Initializing pipeline for SimplePipeline with options hash 995a146ad601044538e6a923bea22f4e
# 2025-10-22 12:28:40,660 - INFO - Processing document job_description.docx
# 2025-10-22 12:28:40,680 - INFO - Finished converting document job_description.docx in 0.03 sec.

# %%
convert_and_save("data/sample.xlsx")
# Out:
# 2025-10-22 12:28:40,689 - INFO - detected formats: [<InputFormat.XLSX: 'xlsx'>]
# 2025-10-22 12:28:40,694 - INFO - Going to convert document batch...
# 2025-10-22 12:28:40,695 - INFO - Processing document sample.xlsx
# 2025-10-22 12:28:40,695 - INFO - Processing sheet 0: Data
# 2025-10-22 12:28:40,696 - INFO - Finished converting document sample.xlsx in 0.00 sec.

# %%
convert_and_save("data/finance and health rag system.jpg")
# Out:
# 2025-10-22 12:28:40,713 - INFO - detected formats: [<InputFormat.IMAGE: 'image'>]
# 2025-10-22 12:28:40,883 - INFO - Going to convert document batch...
# 2025-10-22 12:28:40,884 - INFO - Processing document finance and health rag system.jpg
# 2025-10-22 12:28:43,276 - INFO - Finished converting document finance and health rag system.jpg in 2.58 sec.

# %% [markdown]
# ## Extract Tables

# %%
os.makedirs("docling/tables", exist_ok=True)

# %%
converter = DocumentConverter()

file_path = "data/Apple-10-Q-2025-Q1.pdf"
file_path = Path(file_path)

result = converter.convert(file_path)
# Out:
# 2025-10-22 12:28:43,314 - INFO - detected formats: [<InputFormat.PDF: 'pdf'>]
# 2025-10-22 12:28:43,322 - INFO - Going to convert document batch...
# 2025-10-22 12:28:43,322 - INFO - Initializing pipeline for StandardPdfPipeline with options hash 4f2edc0f7d9bb60b38ebfecf9a2609f5
# 2025-10-22 12:28:43,323 - INFO - Accelerator device: 'cuda:0'
# [INFO] 2025-10-22 12:28:43,332 [RapidOCR] base.py:22: Using engine_name: onnxruntime
# [INFO] 2025-10-22 12:28:43,335 [RapidOCR] download_file.py:60: File exists and is valid: C:\Users\laxmi\anaconda3\envs\ml\Lib\site-packages\rapidocr\models\ch_PP-OCRv4_det_infer.onnx
# [INFO] 2025-10-22 12:28:43,335 [RapidOCR] main.py:53: Using C:\Users\laxmi\anaconda3\envs\ml\Lib\site-packages\rapidocr\models\ch_PP-OCRv4_det_infer.onnx
# [INFO] 2025-10-22 12:28:43,381 [RapidOCR] base.py:22: Using engine_name: onnxruntime
# [INFO] 2025-10-22 12:28:43,382 [RapidOCR] download_file.py:60: File exists and is valid: C:\Users\laxmi\anaconda3\envs\ml\Lib\site-packages\rapidocr\models\ch_ppocr_mobile_v2.0_cls_infer.onnx
# [INFO] 2025-10-22 12:28:43,383 [RapidOCR] main.py:53: Using C:\Users\laxmi\anaconda3\envs\ml\Lib\site-packages\rapidocr\models\ch_ppocr_mobile_v2.0_cls_infer.onnx
# [INFO] 2025-10-22 12:28:43,406 [RapidOCR] base.py:22: Using engine_name: onnxruntime
# [INFO] 2025-10-22 12:28:43,411 [RapidOCR] download_file.py:60: File exists and is valid: C:\Users\laxmi\anaconda3\envs\ml\Lib\site-packages\rapidocr\models\ch_PP-OCRv4_rec_infer.onnx
# [INFO] 2025-10-22 12:28:43,412 [RapidOCR] main.py:53: Using C:\Users\laxmi\anaconda3\envs\ml\Lib\site-packages\rapidocr\models\ch_PP-OCRv4_rec_infer.onnx
# 2025-10-22 12:28:43,477 - INFO - Auto OCR model selected rapidocr with onnxruntime.
# 2025-10-22 12:28:43,478 - INFO - Accelerator device: 'cuda:0'
# 2025-10-22 12:28:44,243 - INFO - Accelerator device: 'cuda:0'
# 2025-10-22 12:28:44,499 - INFO - Processing document Apple-10-Q-2025-Q1.pdf
# 2025-10-22 12:28:59,062 - INFO - Finished converting document Apple-10-Q-2025-Q1.pdf in 15.73 sec.

# %%
for i, table in enumerate(result.document.tables):
    df = table.export_to_dataframe()

    df.to_csv(f"docling/tables/{file_path.stem}_table_{i+1}.csv", index=False)
# Out:
# 2025-10-22 12:28:59,071 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-22 12:28:59,079 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-22 12:28:59,080 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-22 12:28:59,081 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-22 12:28:59,082 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-22 12:28:59,085 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-22 12:28:59,086 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-22 12:28:59,088 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-22 12:28:59,089 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-22 12:28:59,090 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-22 12:28:59,091 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-22 12:28:59,094 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-22 12:28:59,095 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-22 12:28:59,096 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-22 12:28:59,097 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-22 12:28:59,098 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-22 12:28:59,099 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-22 12:28:59,100 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-22 12:28:59,100 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-22 12:28:59,102 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-22 12:28:59,102 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-22 12:28:59,104 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-22 12:28:59,105 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-22 12:28:59,106 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-22 12:28:59,107 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.

# %% [markdown]
# ## Extract Figures

# %%
from docling.document_converter import DocumentConverter
from docling.datamodel.pipeline_options import PdfPipelineOptions
from docling.datamodel.base_models import InputFormat
from docling.document_converter import PdfFormatOption

# %%
os.makedirs("docling/figures", exist_ok=True)

# %%
pipeline_options = PdfPipelineOptions()
# ✅ 强制启用 OCR
pipeline_options.do_ocr = True

pipeline_options.generate_picture_images = True
pipeline_options.images_scale = 3.0

converter = DocumentConverter(
    format_options={
        InputFormat.PDF: PdfFormatOption(
            pipeline_options=pipeline_options
            )})

# %%
from docling.datamodel.pipeline_options import PdfPipelineOptions, AcceleratorDevice, AcceleratorOptions
from docling.datamodel.base_models import InputFormat
from docling.document_converter import DocumentConverter, PdfFormatOption

# 1. 配置加速器：显式指定使用 CUDA
# 如果你有多个 GPU，可以指定 device_id=0
accelerator_options = AcceleratorOptions(
    num_threads=8, 
    device=AcceleratorDevice.CUDA 
)

pipeline_options = PdfPipelineOptions()
pipeline_options.do_ocr = True
pipeline_options.generate_picture_images = True
pipeline_options.images_scale = 2.0

# 将加速器配置注入 pipeline_options
pipeline_options.accelerator_options = accelerator_options

converter = DocumentConverter(
    format_options={
        InputFormat.PDF: PdfFormatOption(
            pipeline_options=pipeline_options
        )
    }
)

# %%
file_path = "data/sample_textbook.pdf"
file_path = Path(file_path)

result = converter.convert(file_path)
# Out:
# [INFO] 2026-02-23 17:13:14,887 [RapidOCR] base.py:22: Using engine_name: onnxruntime
# [INFO] 2026-02-23 17:13:14,891 [RapidOCR] download_file.py:60: File exists and is valid: D:\Anaconda\envs\langchainv1.0\Lib\site-packages\rapidocr\models\ch_PP-OCRv4_det_infer.onnx
# [INFO] 2026-02-23 17:13:14,892 [RapidOCR] main.py:53: Using D:\Anaconda\envs\langchainv1.0\Lib\site-packages\rapidocr\models\ch_PP-OCRv4_det_infer.onnx
# [INFO] 2026-02-23 17:13:14,968 [RapidOCR] base.py:22: Using engine_name: onnxruntime
# [INFO] 2026-02-23 17:13:14,970 [RapidOCR] download_file.py:60: File exists and is valid: D:\Anaconda\envs\langchainv1.0\Lib\site-packages\rapidocr\models\ch_ppocr_mobile_v2.0_cls_infer.onnx
# [INFO] 2026-02-23 17:13:14,970 [RapidOCR] main.py:53: Using D:\Anaconda\envs\langchainv1.0\Lib\site-packages\rapidocr\models\ch_ppocr_mobile_v2.0_cls_infer.onnx
# [INFO] 2026-02-23 17:13:15,013 [RapidOCR] base.py:22: Using engine_name: onnxruntime
# [INFO] 2026-02-23 17:13:15,020 [RapidOCR] download_file.py:60: File exists and is valid: D:\Anaconda\envs\langchainv1.0\Lib\site-packages\rapidocr\models\ch_PP-OCRv4_rec_infer.onnx
# [INFO] 2026-02-23 17:13:15,021 [RapidOCR] main.py:53: Using D:\Anaconda\envs\langchainv1.0\Lib\site-packages\rapidocr\models\ch_PP-OCRv4_rec_infer.onnx

# %%
for i, picture in enumerate(result.document.pictures):
    image = picture.get_image(result.document)

    image.save(f"docling/figures/{file_path.stem}_figure_{i+10}.png")

# %%
from docling.datamodel.pipeline_options import PdfPipelineOptions, AcceleratorOptions, AcceleratorDevice

# 尝试强制指定
acc_options = AcceleratorOptions(device=AcceleratorDevice.CUDA)
pipeline_options = PdfPipelineOptions(accelerator_options=acc_options)

# 打印一下，看看对象是否正确赋值
print(f"预设设备: {pipeline_options.accelerator_options.device}")
# Out:
# 预设设备: AcceleratorDevice.CUDA

# %%
import onnxruntime as ort

providers = ort.get_available_providers()
print(f"可用提供者: {providers}")

if 'CUDAExecutionProvider' not in providers:
    print("❌ 警告：ONNX Runtime 无法识别 CUDA！")
else:
    print("✅ 成功：ONNX Runtime 已识别 CUDA。")
# Out:
# 可用提供者: ['TensorrtExecutionProvider', 'CUDAExecutionProvider', 'CPUExecutionProvider']
# ✅ 成功：ONNX Runtime 已识别 CUDA。
